# %%
# !pip install -U langchain-tavily  #New package
# Out:
# ERROR: Invalid requirement: '#New': Expected package name at the start of dependency specifier
#     #New
#     ^

# %%
import os
from dotenv import load_dotenv

from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.tools import Tool
from langchain_tavily import TavilySearch

# 🔐 Load API Keys
load_dotenv(dotenv_path=".env")

# 🔸 Initialize LLM
llm = ChatOpenAI(
    model="gpt-4.1-mini",
    temperature=0,
    api_key = "your api key"


)
# ✅ Tool 1: Simple QA

qa_prompt = ChatPromptTemplate.from_template(
    "Answer clearly: {question}"
)

qa_chain = qa_prompt | llm

qa_tool = Tool(
    name="Simple QA",
    func=lambda question: qa_chain.invoke(
        {"question": question}
    ).content,
    description="Answer factual questions clearly"
)

# ✅ Tool 2: Summarizer

summary_prompt = ChatPromptTemplate.from_template(
    "Summarize the following text:\n\n{text}"
)

summary_chain = summary_prompt | llm

summary_tool = Tool(
    name="Summarizer",
    func=lambda text: summary_chain.invoke(
        {"text": text}
    ).content,
    description="Summarizes input text"
)

# ✅ Tool 3: Web Search (Tavily)

search_tool = TavilySearch(
    max_results=3,
    tavily_api_key = "tavily api key"
)

# 🧪 Test Inputs

qa_query = "What is LangGraph in LangChain?"

summary_text = """
LangGraph is a framework for building stateful multi-step agents using LangChain.
It uses graph-based design to model agent workflows and memory.
"""

search_query = "Latest updates on GPT-4o by OpenAI"

# 🚀 Run Tools

print("\n🧠 Simple QA Tool Output:\n")
print(qa_tool.invoke(qa_query))

print("\n📝 Summarizer Tool Output:\n")
print(summary_tool.invoke(summary_text))

print("\n🌐 Web Search Tool Output:\n")
print(search_tool.invoke(search_query))
# Out:
# 🧠 Simple QA Tool Output:
#
# LangGraph in LangChain is a tool or component designed to represent and manage the flow of data and operations within a LangChain application as a graph structure. It helps visualize and orchestrate how different language model calls, chains, and data transformations connect and interact, making it easier to build, debug, and optimize complex workflows involving multiple steps and components.
#
# 📝 Summarizer Tool Output:
#
# LangGraph is a framework that leverages graph-based design to create stateful, multi-step agents with LangChain, enabling the modeling of agent workflows and memory.
#
# 🌐 Web Search Tool Output:
#
# {'query': 'Latest updates on GPT-4o by OpenAI', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://community.openai.com/t/chatgpt-release-notes-2025-march-27-gpt-4o-a-new-update/1153887', 'title': 'ChatGPT — Release Notes: 2025-March-27 - GPT-4o a new update - Community - OpenAI Developer Community', 'content': '# ChatGPT — Release Notes: 2025-March-27 - GPT-4o a new update\n\nOpenAI just gave GPT-4o a new update. Based on content on OpenAI help page:\n\nThis model is now available in ChatGPT and in the API as the newest snapshot of chatgpt-4o-latest.\n\nWe plan to bring these improvements to a dated model in the API in the coming weeks.\n\nDoes this affect GPT-4o-mini too, or just GPT-4o?\n\nGenerally, I don’t use 4o mini.\n\nBut I just tested, it is same on my end. [...] Thank the gods. The January update was so bad at following instructions, catching and prepresenting nuance, terrible at coding, that I was looking at Gemini, Claude, and DeepSeek as alternatives (turns out they were little better). The subtle, careful, and accurate experience I had come to expect all through 2024 was tossed out the window. My anecdotal experience was that the Jan GPT-4o update was less helpful than the original GPT-3.5 we got in Nov 2022.', 'score': 0.8886914, 'raw_content': None, 'id': 'b0347c-00'}, {'url': 'https://help.openai.com/en/articles/9624314-model-release-notes', 'title': 'Model Release Notes | OpenAI Help Center', 'content': 'We’ve updated GPT-4o for ChatGPT users on all paid tiers. This update to GPT-4o includes improved writing capabilities that are now more natural, audience-aware, and tailored to improve relevance and readability. This model is also better at working with uploaded files, able to provide deeper insights and more thorough responses.\n\n### Update to GPT 4o-mini (November 5, 2024) [...] ## Improvements to GPT-4o (March 27, 2025)\n\nWe’ve made improvements to GPT-4o—it now feels more intuitive, creative, and collaborative, with enhanced instruction-following, smarter coding capabilities, and a clearer communication style.\n\n### Smarter problem-solving in STEM and coding: [...] We’re making additional improvements to GPT-4o, optimizing when it saves memories and enhancing problem-solving capabilities for STEM. We’ve also made subtle changes to the way it responds, making it more proactive and better at guiding conversations toward productive outcomes. We think these updates help GPT-4o feel more intuitive and effective across a variety of tasks–we hope you agree!\n\n## OpenAI o3 and o4-mini (April 16, 2025)', 'score': 0.87782305, 'raw_content': None, 'id': '8a7e79-01'}, {'url': 'https://en.wikipedia.org/wiki/GPT-4o', 'title': 'GPT-4o', 'content': '[edit]\n\nIn August 2024, OpenAI introduced a new feature allowing corporate customers to customize GPT-4o using proprietary company data. This customization, known as fine-tuning "Fine-tuning (deep learning)"), enables businesses to adapt GPT-4o to specific tasks or industries, enhancing its utility in areas like customer service and specialized knowledge domains. Previously, fine-tuning was available only on the less powerful model GPT-4o mini. [...] OpenAI retired GPT-4o from ChatGPT on February 13, 2026, with OpenAI saying that most users had switched to GPT-5.2. The retirement applied only to ChatGPT, and GPT-4o continued to be available through the API. The separate `chatgpt-4o-latest` API snapshot was retired on February 17, 2026, while other GPT-4o snapshots remained available through the API.\n\n## Background\n\n[edit] [...] | GPT-4o |\n\n| Developer | OpenAI |\n| Release | May 13, 2024; 2 years ago (2024-05-13) |\n| Preview release | ChatGPT-4o-latest (2025-03-26) / March 26, 2025; 17 months ago (2025-03-26) |\n|  |\n| Predecessor | GPT-4 Turbo |\n| Successor |  OpenAI o1  GPT-4.5  GPT-5 |\n| Type |  Multimodal  Large language model  Generative pre-trained transformer  Foundation model |\n| License | Proprietary |\n| Websit ...
