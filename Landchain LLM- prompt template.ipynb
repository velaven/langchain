# %%
import os
from dotenv import load_dotenv
#from langchain.chat_models import ChatOpenAI
from langchain_openai import ChatOpenAI
#from langchain.prompts import PromptTemplate
from langchain_core.prompts import ChatPromptTemplate    #change 
#from langchain.chains import LLMChain
from langchain_core.prompts import ChatPromptTemplate

# %%
import os
print(os.listdir())
# Out:
# ['.env', '.ipynb_checkpoints', '1.Langchain_LLM_Prompt_Template.ipynb', '10_LangChain_RAG_Types.ipynb', '11_Langchain_ContextualCompression_v1.ipynb', '12_Langchain_Compressor_As_preprocessing_v1.ipynb', '13)Langchain_Remaining_Types_of_RAG.ipynb', '14)LangChain_types_of_chains.ipynb', '15)MapReduce.ipynb', '16LangChain_outputparser.ipynb', '2.Langchain_LLM_Prompt_Template_Tools_Wrap.ipynb', '3.Langchain_LLM_Prompt_Template_MutipleTool.ipynb', '4.Langchain_LLM_Prompt_Template_MutipleTool_Web.ipynb', '6.Langchain_mutiple_Tools_withAgent.ipynb', '7.Langchain_AgentTypes.ipynb', '8.Tools_Agent_Memory.ipynb', '9.LangchainRAGTool.ipynb', 'Landchain LLM- prompt template.ipynb', 'requirements.txt', 'sample.txt']

# %%
import os
from dotenv import load_dotenv
#from langchain.chat_models import ChatOpenAI

from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
load_dotenv(override=True)
# 🔐 Load API key
load_dotenv(dotenv_path=".env")

# 🔸 Initialize LLM
llm = ChatOpenAI(
    model="gpt-3.5-turbo",
    temperature=0,
    api_key = "your api key"   # Optional if already in environment
)

# 🔸 Create Prompt Template
prompt = ChatPromptTemplate.from_template(
    "Answer clearly: {question}"
)

# 🔸 Create Chain (LCEL)
chain = prompt | llm

# 🚀 Run a query
query = "What is LangGraph in LangChain?"

response = chain.invoke(
    {"question": "what is langchain"})
print("\nLLM Answer:", response.content)
# Out:
# LLM Answer: Langchain is a decentralized platform that aims to connect language learners with native speakers for language exchange and practice.
